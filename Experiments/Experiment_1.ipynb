# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhra012/ML/blob/main/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded=files.upload()
# Out:
#      <input type="file" id="files-487f392b-8dd6-48b5-a08a-d371a55966a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-487f392b-8dd6-48b5-a08a-d371a55966a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('temp.csv')

# %%
df
# Out:
#      sky  temp humidity    wind isplay
# 0  sunny  warm     high  strong    yes
# 1  sunny  warm   normal  strong    yes
# 2  rainy  cold     high  strong     no
# 3  sunny  warm     high    less     no

# %%
df.head()
# Out:
#      sky  temp humidity    wind isplay
# 0  sunny  warm     high  strong    yes
# 1  sunny  warm   normal  strong    yes
# 2  rainy  cold     high  strong     no
# 3  sunny  warm     high    less     no

# %%
df.tail()
# Out:
#      sky  temp humidity    wind isplay
# 0  sunny  warm     high  strong    yes
# 1  sunny  warm   normal  strong    yes
# 2  rainy  cold     high  strong     no
# 3  sunny  warm     high    less     no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sky       4 non-null      object
#  1   temp      4 non-null      object
#  2   humidity  4 non-null      object
#  3   wind      4 non-null      object
#  4   isplay    4 non-null      object
# dtypes: object(5)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#           sky  temp humidity    wind isplay
# count       4     4        4       4      4
# unique      2     2        2       2      2
# top     sunny  warm     high  strong    yes
# freq        3     3        3       3      2

# %%
df.shape
# Out:
# (4, 5)

# %%
X=df.drop(columns=["isplay"])

# %%
Y=df["isplay"]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type[Y]
# Out:
# type[0    yes
# 1    yes
# 2     no
# 3     no
# Name: isplay, dtype: object]

# %%
X=np.array(X)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
Y=np.array(Y)

# %%
type(Y)
# Out:
# numpy.ndarray
